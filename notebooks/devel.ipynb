# %% [markdown]
# Considerations a prendre en compte
# - La méthode doit être calculée dans un certain ordre afin de prendre en compte les effets de cascades
# - Les résultats intermédiaires doivent être renvoyé en même temps que mes résultats aggrégés
# - Le recours à des abaques implique d'avoir des validations prenant en compte les choix déjà remplis
# - Certains inputs doivent être multidéclaratif
# - la fonction doit pouvoir se paralleliser
#
# classes à envisager:
# - Classe Abaque :
# - - charge un ou plusieurs csv
# - - clean les champs
# - - propriété pour avoir les valeurs valides de chaque champs
# - - propriété pour avoir les valeurs combinés valides de chaque champs
# - - function to leverage numeric inputs based on upper tresholds
#
# functions:
# - aggregation functions

# %%
files=['.gitkeep',
 'tv001_coefficient_reduction_deperditions.csv',
 'tv002_local_non_chauffe.csv',
 'tv002_local_non_chauffe_type_batiment.csv',
 'tv002_veranda.csv',
 'tv003_umur.csv',
 'tv004_umur0.csv',
 'tv004_umur0_materiaux.csv',
 'tv005bis_ipb_terre_plein.csv',
 'tv005_upb.csv',
 'tv006_upb0.csv',
 'tv007_uph.csv',
 'tv007_uph_type_toit.csv',
 'tv008_uph0.csv',
 'tv009_coefficient_transmission_thermique_vitrage.csv',
 'tv009_ug_orientation.csv',
 'tv009_ug_remplissage.csv',
 'tv009_ug_traitement_vitrage.csv',
 'tv009_ug_type_vitrage.csv',
 'tv010_coefficient_transmission_thermique_baie.csv',
 'tv010_uw_type_baie.csv',
 'tv010_uw_type_materiaux.csv',
 'tv010_uw_type_menuiserie.csv',
 'tv011_resistance_additionnelle.csv',
 'tv012_coefficient_transmission_thermique_baie_protection_solaire.csv',
 'tv013_valeur_pont_thermique.csv',
 'tv013_valeur_pont_thermique_isolation_mur.csv',
 'tv013_valeur_pont_thermique_isolation_plancher_bas.csv',
 'tv013_valeur_pont_thermique_retour_isolation.csv',
 'tv013_valeur_pont_thermique_type_liaison.csv',
 'tv013_valeur_pont_thermique_type_pose.csv',
 'tv014_bis_permeabilite.csv',
 'tv014_permeabilite.csv',
 'tv015_bis_valeur_conventionnelle_renouvellement_air.csv',
 'tv015_valeur_conventionnelle_renouvellement_air.csv',
 'tv016_departement.csv',
 'tv017_zone_hiver.csv',
 'tv018_zone_ete.csv',
 'tv019_fecs.csv',
 'tv019_fecs_anciennete_installation.csv',
 'tv019_fecs_type_installation.csv',
 'tv020_bis_coefficient_orientation.csv',
 'tv020_coefficient_orientation.csv',
 'tv020_coefficient_orientation_inclinaison_paroi.csv',
 'tv020_coefficient_orientation_orientation_paroi.csv',
 'tv021_facteur_solaire.csv',
 'tv021_facteur_solaire_materiaux.csv',
 'tv021_facteur_solaire_type_baie.csv',
 'tv021_facteur_solaire_type_pose.csv',
 'tv021_facteur_solaire_type_vitrage.csv',
 'tv022_coefficient_masques_proches.csv',
 'tv022_coefficient_masques_proches_avance.csv',
 'tv022_coefficient_masques_proches_type_masque.csv',
 'tv023_coefficient_masques_lointains_homogenes.csv',
 'tv023_coefficient_masques_lointains_homogenes_hauteur_alpha.csv',
 'tv024_ombrage_obstacle_lointain.csv',
 'tv024_ombrage_obstacle_lointain_hauteur.csv',
 'tv024_ombrage_obstacle_lointain_secteur.csv',
 'tv025_intermittence.csv',
 'tv025_intermittence_comptage_individuel.csv',
 'tv025_intermittence_equipement_intermittence.csv',
 'tv025_intermittence_inertie.csv',
 'tv025_intermittence_type_batiment.csv',
 'tv025_intermittence_type_chauffage.csv',
 'tv025_intermittence_type_emetteur.csv',
 'tv025_intermittence_type_installation.csv',
 'tv025_intermittence_type_regulation.csv',
 'tv026_classe_inertie.csv',
 'tv026_classe_inertie_type.csv',
 'tv027_pertes_recuperees_ecs.csv',
 'tv027_pertes_recuperees_ecs_type_production.csv',
 'tv027_pertes_recuperees_ecs_type_systeme.csv',
'tv028_rendement_emission_systeme_chauffage.csv',
 'tv029_rendement_distribution_systeme_chauffage.csv',
 'tv030_rendement_regulation_systeme_chauffage.csv',
 'tv031_rendement_generation.csv',
 'tv031_rendement_generation_methode_generation.csv',
 'tv032_coefficient_performance.csv',
 'tv033_coefficient_correction_regulation.csv',
 'tv034_temperature_fonctionnement_chaudiere_100.csv',
 'tv035_temperature_fonctionnement_chaudiere_30.csv',
 'tv035_temperature_fonctionnement_chaudiere_type_chaudiere.csv',
 'tv036_puissance_veilleuse.csv',
 'tv036_puissance_veilleuse_type_chaudiere.csv',
 'tv037_puissance_necessaire_production_ecs.csv',
 'tv038_puissance_nominale.csv',
 'tv038_puissance_nominale_type_chaudiere.csv',
 'tv038_puissance_nominale_type_installation.csv',
 'tv039_formule_becs.csv',
 'tv040_rendement_distribution_ecs.csv',
 'tv040_rendement_distribution_ecs_type_generateur.csv',
 'tv040_rendement_distribution_ecs_type_installation.csv',
 'tv041_coefficient_emplacement_fonctionnement.csv',
 'tv041_coefficient_emplacement_fonctionnement_alimentation.csv',
 'tv042_tarif_energie.csv',
 'tv042_tarif_energie_type_energie.csv',
 'tv043_pertes_stockage.csv',
 'tv044_conversion_kwh_energies_relevees.csv',
 'tv044_conversion_kwh_energies_relevees_type_energie.csv',
 'tv044_conversion_kwh_energies_relevees_unite.csv',
 'tv045_conversion_kwh_co2.csv',
 'tv046_evaluation_contenu_co2_reseaux.csv',
 'tv046_evaluation_contenu_co2_reseaux_type_production.csv',
 'tv047_rendement_generation_ecs.csv',
 'tv048_rendement_stockage_ecs.csv',
 'tv049_perte_stockage_ecs.csv',
 'tv0xx_orientation.csv',
 'tv0xx_temperature_distribution.csv',
 'tv0xx_type_emetteur.csv',
 'vide_sanitaire.xlsx']

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import os
import numpy as np
import sys
sys.path.append('../src/')

pd.set_option('display.max_columns', 500)

from py3CL import DPE, DPEInput
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
configs_path='../src/configs/'

abaques_configs={
    "department":os.path.join(configs_path,'departments.yaml'),
    "local_non_chauffe":os.path.join(configs_path,'local_non_chauffe.yaml'),
    "coef_reduction_deperdition_local": os.path.join(configs_path,'coef_reduction_deperdition_local.yaml'),
    "coef_reduction_deperdition_exterieur": os.path.join(configs_path,'coef_reduction_deperdition_exterieur.yaml'),
    "coef_reduction_veranda": os.path.join(configs_path,'coef_reduction_veranda.yaml'),
    "umur0":os.path.join(configs_path,'umur0.yaml'),
    "umur":os.path.join(configs_path,'umur.yaml'),
    "upb0":os.path.join(configs_path,'upb0.yaml'),
    "upb":os.path.join(configs_path,'upb.yaml'),
    'upb_tp':os.path.join(configs_path,'upb_tp.yaml'),
    "uph":os.path.join(configs_path,'uph.yaml'),
    "uph0":os.path.join(configs_path,'uph0.yaml'),
    "ug_vitrage":os.path.join(configs_path,'ug_vitrage.yaml'),
    "uw_vitrage":os.path.join(configs_path,'uw_vitrage.yaml'),
    "resistance_additionnelle_vitrage":os.path.join(configs_path,'resistance_additionnelle_vitrage.yaml'),
    "transmission_thermique_baie":os.path.join(configs_path,'transmission_thermique_baie.yaml'),
    "kpth":os.path.join(configs_path,'kpth.yaml'),
    "permeabilite_fenetre":os.path.join(configs_path,'permeabilite_fenetre.yaml'),
    "permeabilite_batiment":os.path.join(configs_path,'permeabilite_batiment.yaml'),
    "renouvellement_air":os.path.join(configs_path,'renouvellement_air.yaml'),
}

dpe=DPE(configs=abaques_configs)
# Out:
# department
# Abaque(tv016_departement.csv)
# Keys: ['id']
# Values: ['altmin', 'altmax', 'nref', 'dhref', 'pref', 'c2', 'c3', 'c4', 't_ext_basse', 'e', 'fch', 'fecs_ancienne_m_i', 'fecs_recente_m_i', 'fecs_solaire_m_i', 'fecs_ancienne_i_c', 'fecs_recente_i_c', 'zone_climatique']
#
# local_non_chauffe
# Abaque(tv002_local_non_chauffe.csv)
# Keys: ['type_batiment', 'local_non_chauffe']
# Values: ['uvue']
#
# coef_reduction_deperdition_local
# Abaque(tv001_coefficient_reduction_deperditions.csv)
# Keys: ['aiu_aue_max', 'aue_isole', 'aiu_isole', 'uv_ue']
# Values: ['valeur']
#
# coef_reduction_deperdition_exterieur
# Abaque(tv001_coefficient_reduction_deperditions.csv)
# Keys: ['aiu_aue']
# Values: ['valeur']
#
# coef_reduction_veranda
# Abaque(tv002_veranda.csv)
# Keys: ['zone_climatique', 'orientation_veranda', 'isolation_paroi']
# Values: ['bver']
#
# umur0
# Abaque(tv004_umur0.csv)
# Keys: ['umur0_materiaux', 'epaisseur']
# Values: ['umur']
#
# umur
# Abaque(tv003_umur.csv)
# ...

# %%
dpe.abaques['renouvellement_air'].valid_cat_combinations, dpe.abaques['renouvellement_air'].key_characteristics
# Out:
# ([{'type_ventilation': 'Ventilation par ouverture des fenêtres'},
#   {'type_ventilation': "Ventilation par entrées d'air hautes et basses"},
#   {'type_ventilation': 'VMC SF Auto réglable < 1982'},
#   {'type_ventilation': 'VMC SF Auto réglable de 1982 à 2000'},
#   {'type_ventilation': 'VMC SF Auto réglable de 2001 à 2012'},
#   {'type_ventilation': 'VMC SF Auto réglable après 2012'},
#   {'type_ventilation': 'VMC SF Hygro A < 2001'},
#   {'type_ventilation': 'VMC SF Hygro A de 2001 à 2012'},
#   {'type_ventilation': 'VMC SF Hygro A après 2012'},
#   {'type_ventilation': 'VMC SF Gaz < 2001'},
#   {'type_ventilation': 'VMC SF Gaz de 2001 à 2012'},
#   {'type_ventilation': 'VMC SF Gaz après 2012'},
#   {'type_ventilation': 'VMC SF Hygro B < 2001'},
#   {'type_ventilation': 'VMC SF Hygro B de 2001 à 2012'},
#   {'type_ventilation': 'VMC SF Hygro B après 2012'},
#   {'type_ventilation': 'VMC Basse pression Auto-réglable'},
#   {'type_ventilation': 'VMC Basse pression Hygro A'},
# ...

# %%
dpe.abaques['coef_reduction_veranda']
# Out:
# Abaque(tv002_veranda.csv)
# Keys: ['zone_climatique', 'orientation_veranda', 'isolation_paroi']
# Values: ['bver']

# %%
input_data = {
    "postal_code": "75015",
    "adress": "127 rue lecourbe",
    "city": "Paris",
    "country": "France",
    "type_logement": "Maison individuelle",
    "surface_habitable": 100,
}

dpe_input = DPEInput(**input_data)

result = dpe.forward(dpe_input)
result
# Out:
# {'postal_code': '75015',
#  'adress': '127 rue lecourbe',
#  'city': 'Paris',
#  'country': 'France',
#  'type_logement': 'Maison individuelle',
#  'department': 75,
#  'zone_climatique': 'H1b',
#  'zone_hiver': 'H1'}
